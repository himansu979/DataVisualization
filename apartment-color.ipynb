# %% [markdown]
# # Histogram Equalization

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
orig = plt.imread('kitchen-org.jpg')
#orig = plt.imread('image4.jpeg')
#orig = plt.imread('APT1.jpg')
##orig = orig_1.mean(axis=2)
plt.imshow(orig)

# %%
#orig[0:2]

# %%
#plt.imshow(orig_1, cmap="gray") # colored imaged, will not show in gray scale, need to convert to 2D

# %%
plt.imshow(orig, cmap="gray")

# %%
print(orig.shape)
orig.min(), orig.max()
# Out:
# (800, 1600, 3)
# (0, 255)

# %%
pixels = orig.flatten()
plt.hist(pixels, bins = 256, range = (0, 256), normed = True, color = 'blue', alpha =0.3)
plt.show()
minval, maxval = orig.min(), orig.max()
print(minval, maxval)
# Out:
# C:\Users\hisahoo.ISC\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 0 255

# %%
plt.hist(pixels, bins =256, range = (0, 256),  normed = True, color = 'blue', alpha = 0.3)
plt.twinx()
orig_cdf, bins, patches = plt.hist(pixels, cumulative = True, bins = 256, range = (0, 256), normed = True, color = 'red', alpha = 0.3)
plt.title('Image histogram and CDF')
plt.xlim((0, 255))
plt.show()
# Out:
# C:\Users\hisahoo.ISC\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(16,8)) # figsize is in inches
fig=plt.imshow(orig, cmap="gray")
plt.axis('off')
fig.axes.get_xaxis().set_visible(False)
fig.axes.get_yaxis().set_visible(False)
#plt.title('Equalized image')
#plt.show()

plt.savefig("kitchen-grayscale.jpg", transparent = True, bbox_inches='tight', pad_inches = -0.1)

# %%
#plt.imshow(new, cmap="gray")
#plt.show()
new_pixels = np.interp(pixels, bins[:-1], orig_cdf*255)
new = new_pixels.reshape(orig.shape)
plt.figure(figsize=(16,8))
fig=plt.imshow(np.uint8(new), cmap="gray")
plt.axis('off')
fig.axes.get_xaxis().set_visible(False)
fig.axes.get_yaxis().set_visible(False)
#plt.title('Equalized image')
#plt.show()

plt.savefig("kitchen-hist-grayscale.jpg", transparent = True, bbox_inches='tight', pad_inches = -0.1)

# %%
print(new_pixels.shape)
print(new.shape)
# Out:
# (3840000,)
# (800, 1600, 3)

# %%
# print(new_pixels[0:10])
# print(new[0:5])

# %%
plt.hist(new_pixels, bins=256, range=(0,256), normed=True, color="blue", alpha=0.3);
plt.twinx()
orig_cdf, bins, patches = plt.hist(new_pixels, cumulative = True, bins = 256, range = (0, 256), normed = True, color = 'red', alpha = 0.3)
plt.title('Image histogram and CDF')
plt.xlim((0, 255))
plt.show()
# Out:
# C:\Users\hisahoo.ISC\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
